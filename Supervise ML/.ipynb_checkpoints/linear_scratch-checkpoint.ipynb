# %%
import numpy as np

# %%
# Linear Regression 

class LinearRegression:
    def __init__(self, learning_rate=0.01, n_iter=1000):
        self.bias = None
        self.weights = None
        self.lr = learning_rate
        self.n_iter = n_iter

    def fit(self, X,y): # X_train, y_train
        m, n = X.shape # (number of samples, number, number of features)

        self.bias = 0
        self.weights = np.zeros(n) # [0, 0, ....0]

    def predict(self, ):
