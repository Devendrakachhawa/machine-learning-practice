# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\devendra kachhawa\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    - -------------------------------------- 1.8/40.2 MB 36.2 MB/s eta 0:00:02
#    --------- ------------------------------ 10.0/40.2 MB 37.4 MB/s eta 0:00:01
#    ------------- -------------------------- 13.1/40.2 MB 26.5 MB/s eta 0:00:02
#    -------------- ------------------------- 14.4/40.2 MB 22.4 MB/s eta 0:00:02
#    -------------- ------------------------- 14.9/40.2 MB 17.2 MB/s eta 0:00:02
#    --------------- ------------------------ 15.7/40.2 MB 14.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.5/40.2 MB 12.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.8/40.2 MB 11.4 MB/s eta 0:00:02
#    ------------------- -------------------- 19.1/40.2 MB 10.7 MB/s eta 0:00:02
#    -------------------- ------------------- 20.7/40.2 MB 10.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 22.3/40.2 MB 10.1 MB/s eta 0:00:02
#    ------------------------ --------------- 24.4/40.2 MB 9.9 MB/s eta 0:00:02
#    -------------------------- ------------- 26.2/40.2 MB 9.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 28.6/40.2 MB 9.9 MB/s eta 0:00:02
#    ------------------------------- -------- 31.5/40.2 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 34.3/40.2 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------- -- 37.2/40.2 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 10.3 MB/s  0:00:04
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
# Read image 
img = cv2.imread("image.jpg")



img
# Show image 
# img = cv2.imshow("Image", img)

# cv2.waitkey(0)
# cv2.destoryAllwindow()
# Out:
# array([[[80, 66, 44],
#         [81, 67, 45],
#         [82, 68, 45],
#         ...,
#         [80, 64, 41],
#         [79, 64, 38],
#         [79, 64, 38]],
#
#        [[80, 66, 44],
#         [81, 67, 45],
#         [81, 67, 44],
#         ...,
#         [79, 63, 40],
#         [79, 64, 38],
#         [78, 63, 37]],
#
#        [[80, 66, 44],
#         [80, 66, 44],
#         [82, 66, 43],
#         ...,
#         [78, 62, 39],
#         [78, 63, 37],
#         [78, 63, 37]],
#
#        ...,
#
#        [[16,  3,  1],
#         [16,  3,  1],
#         [16,  3,  1],
#         ...,
#         [72, 46,  0],
#         [67, 42,  0],
#         [66, 41,  0]],
#
#        [[16,  3,  1],
#         [16,  3,  1],
#         [16,  3,  1],
#         ...,
#         [77, 51,  5],
#         [72, 47,  3],
#         [70, 45,  1]],
#
#        [[16,  3,  1],
#         [16,  3,  1],
#         [16,  3,  1],
#         ...,
#         [72, 46,  0],
#         [69, 44,  0],
#         [72, 47,  3]]], shape=(853, 1280, 3), dtype=uint8)

# %%
img
# Out:
# array([[[80, 66, 44],
#         [81, 67, 45],
#         [82, 68, 45],
#         ...,
#         [80, 64, 41],
#         [79, 64, 38],
#         [79, 64, 38]],
#
#        [[80, 66, 44],
#         [81, 67, 45],
#         [81, 67, 44],
#         ...,
#         [79, 63, 40],
#         [79, 64, 38],
#         [78, 63, 37]],
#
#        [[80, 66, 44],
#         [80, 66, 44],
#         [82, 66, 43],
#         ...,
#         [78, 62, 39],
#         [78, 63, 37],
#         [78, 63, 37]],
#
#        ...,
#
#        [[16,  3,  1],
#         [16,  3,  1],
#         [16,  3,  1],
#         ...,
#         [72, 46,  0],
#         [67, 42,  0],
#         [66, 41,  0]],
#
#        [[16,  3,  1],
#         [16,  3,  1],
#         [16,  3,  1],
#         ...,
#         [77, 51,  5],
#         [72, 47,  3],
#         [70, 45,  1]],
#
#        [[16,  3,  1],
#         [16,  3,  1],
#         [16,  3,  1],
#         ...,
#         [72, 46,  0],
#         [69, 44,  0],
#         [72, 47,  3]]], shape=(853, 1280, 3), dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.show()
